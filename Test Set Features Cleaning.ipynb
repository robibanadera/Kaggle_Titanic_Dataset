# %% [markdown]
# # TEST DATA

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('test.csv')
display(df)
display(df.info())
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ## Check and drop duplicates

# %%
df = df.drop_duplicates(keep = 'first')
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ## Check for null values and replace or remove

# %%
display(df.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
null_cols = ['Age', 'Cabin', 'Embarked']

for i in null_cols:
    display(df[df[i].isnull() == True])
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df = df.drop(columns = ['Name', 'Cabin', 'Ticket'])
df.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0          892       3    male  34.5      0      0   7.8292        Q
# 1          893       3  female  47.0      1      0   7.0000        S
# 2          894       2    male  62.0      0      0   9.6875        Q
# 3          895       3    male  27.0      0      0   8.6625        S
# 4          896       3  female  22.0      1      1  12.2875        S

# %%
print('Old')
display(df.groupby('Embarked')['PassengerId'].count())

df['Embarked'].fillna(value='S', inplace=True)

print('New')
display(df.groupby('Embarked')['PassengerId'].count())
# Out:
# Old
# Embarked
# C    102
# Q     46
# S    270
# Name: PassengerId, dtype: int64
# New
# Embarked
# C    102
# Q     46
# S    270
# Name: PassengerId, dtype: int64

# %%
int(df['Age'].mode().mean())
# Out:
# 22

# %%
print('Old')
display(df[df['Age'].isnull() == True])

age_mode = float(df['Age'].mode().mean())
df['Age'].fillna(value=age_mode, inplace=True)

print('New')
display(df[df['Age'].isnull() == True])
# Out:
# Old
#      PassengerId  Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 10           902       3    male  NaN      0      0   7.8958        S
# 22           914       1  female  NaN      0      0  31.6833        S
# 29           921       3    male  NaN      2      0  21.6792        C
# 33           925       3  female  NaN      1      2  23.4500        S
# 36           928       3  female  NaN      0      0   8.0500        S
# ..           ...     ...     ...  ...    ...    ...      ...      ...
# 408         1300       3  female  NaN      0      0   7.7208        Q
# 410         1302       3  female  NaN      0      0   7.7500        Q
# 413         1305       3    male  NaN      0      0   8.0500        S
# 416         1308       3    male  NaN      0      0   8.0500        S
# 417         1309       3    male  NaN      1      1  22.3583        C
#
# [86 rows x 8 columns]
# New
# Empty DataFrame
# Columns: [PassengerId, Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
# ...

# %%
print('Old')
display(df[df['Fare'].isnull() == True])

fare_mean = df['Fare'].mean()
df['Fare'].fillna(value=fare_mean, inplace=True)

print('New')
display(df[df['Fare'].isnull() == True])
# Out:
# Old
#      PassengerId  Pclass   Sex   Age  SibSp  Parch  Fare Embarked
# 152         1044       3  male  60.5      0      0   NaN        S
# New
# Empty DataFrame
# Columns: [PassengerId, Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]
# Index: []

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Properly label the variables

# %%
df_clean = df

# %%
#Embarked
for place in df_clean['Embarked']:
    if place == 'S':
        df_clean['Embarked'] = df_clean['Embarked'].replace([place],'Southampton')
    elif place == 'C':
        df_clean['Embarked'] = df_clean['Embarked'].replace([place],'Cherbourg')
    elif place == 'Q':
        df_clean['Embarked'] = df_clean['Embarked'].replace([place],'Queenstown')

#Sex
df_clean['Sex'].replace({'male': 'Male', 'female': 'Female'}, inplace=True)

#Pclass
df_clean['Pclass'] = df_clean['Pclass'].astype(str)
df_clean['Pclass'].replace({'1':'1st Class', '2':'2nd Class', '3':'3rd Class'}, inplace=True)

df_clean.head()
# Out:
#    PassengerId     Pclass     Sex   Age  SibSp  Parch     Fare     Embarked
# 0          892  3rd Class    Male  34.5      0      0   7.8292   Queenstown
# 1          893  3rd Class  Female  47.0      1      0   7.0000  Southampton
# 2          894  2nd Class    Male  62.0      0      0   9.6875   Queenstown
# 3          895  3rd Class    Male  27.0      0      0   8.6625  Southampton
# 4          896  3rd Class  Female  22.0      1      1  12.2875  Southampton

# %%
# df_clean.to_csv('test_clean.csv', index=False)
